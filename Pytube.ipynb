# %%
pip install --upgrade pytube
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytube import YouTube
yt = YouTube('https://www.youtube.com/watch?v=D_E62X_z0jc&t=2196s')
streams = yt.streams.filter(file_extension='mp4').get_highest_resolution().download('/Users/masontaylor/downloads/Fall 2023/CSC-475/Project/Dataset/Clips')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/b5/xk6gdm191jgfc3mj34jg7zbh0000gn/T/ipykernel_24429/1477799936.py in <module>
#       1 from pytube import YouTube
# ----> 2 yt = YouTube('https://www.youtube.com/watch?v=D_E62X_z0jc&t=2196s')
#       3 streams = yt.streams.filter(file_extension='mp4').get_highest_resolution().download('/Users/masontaylor/downloads/Fall 2023/CSC-475/Project/Dataset/Clips')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pytube/__main__.py in __init__(self, url, defer_prefetch_init, on_progress_callback, on_complete_callback, proxies)
#      89
#      90         if not defer_prefetch_init:
# ---> 91             self.prefetch()
#      92             self.descramble()
#      93
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pytube/__main__.py in prefetch(self)
#     179             )
#     180
# ...
